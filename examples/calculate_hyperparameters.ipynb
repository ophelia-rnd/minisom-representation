# %%
RANDOM_SEED = 42
VERBOSE = True

# %%
# load dataset
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True, as_frame=False)
# scale data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from minisom_representation import SomRepresentation, calc_recommended_lattice_sides, calc_initial_sigma

# %%
# retrieve recommended parameters
d1_rec, d2_rec = calc_recommended_lattice_sides(X_scaled)
sigma_rec = calc_initial_sigma(d1_rec, d2_rec)
print("Recommended parameters: ", f"d1={d1_rec}, d2={d2_rec}, sigma={sigma_rec}")
# Out:
# Recommended parameters:  d1=6, d2=11, sigma=5.5

# %%
# manually define parameters based on recommendations
d1, d2 = d1_rec * 2, d2_rec * 2
sigma = sigma_rec * 2.5
print("Defined parameters: ", f"d1={d1}, d2={d2}, sigma={sigma}")
# Out:
# Defined parameters:  d1=12, d2=22, sigma=13.75

# %%
# fit SOM representation
som_rep = SomRepresentation(d1=d1, d2=d2, sigma=sigma, random_seed=RANDOM_SEED, verbose=VERBOSE)
som_rep.fit_offline(X_scaled)
# Out:
#  [ 20 / 20 ] 100% - 0:00:00 left Quantization Error: 0.6722
#
#  An SOM representation has been fitted as follows:
# -------------------------------------------------------
#
# Fit strategy: offline
#
# Hyperparameters of SOM:
#
# {'input_len': 4, 'x': 12, 'y': 22, 'sigma': np.float64(13.75), 'topology': 'rectangular', 'learning_rate': 0.5, 'decay_function': 'asymptotic_decay', 'sigma_decay_function': 'asymptotic_decay', 'neighborhood_function': 'gaussian', 'activation_distance': 'euclidean', 'random_seed': 42, 'num_iteration': 20, 'verbose': True}
#
# Quality of SOM:
#
# Quantization Error (QE):	0.6722371672197319
# Topographic Error (TE): 	0.0
